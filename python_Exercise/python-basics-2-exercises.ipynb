# %% [markdown]
# # Python Basics — Part 2 Practice Exercises
#
# **Estimated time:** ~6 hours (part of the Part 2 level, alongside `python-basics-2-guide.ipynb`).
#
# These exercises match the topics in `python-basics-2-guide.ipynb`.
#
# ## How to Use This Notebook
#
# - Read the instructions in each markdown cell.
# - Write your code in the empty code cell below it.
# - Run a cell with **Shift + Enter**.
# - Try each exercise yourself before looking anything up.
# - Read error messages carefully; they usually tell you what went wrong.

# %% [markdown]
# ## Exercise 1: String Slicing
#
# Use the variable `word` below.
#
# 1. Print the first character.
# 2. Print the last character.
# 3. Print the first three characters using a slice.
# 4. Print the whole word reversed.
# 5. Print the length of the word.

# %%
word = "programming"
# Your code here

print(word[0]) 
print(word[-1])
print(word[:3])
print(word[::-1])
print(len(word))
# Out:
# p
# g
# pro
# gnimmargorp
# 11

# %% [markdown]
# ## Exercise 2: String Methods
#
# Use the variable `sentence` below.
#
# 1. Remove the extra spaces at the start and end.
# 2. Print the sentence in uppercase.
# 3. Print how many times the letter `o` appears.
# 4. Check and print whether it starts with `"the"` (after stripping).
# 5. Split the cleaned sentence into a list of words and print it.

# %%
sentence = "   the cat sat on the mat   "
# Your code here

# %% [markdown]
# ## Exercise 3: Formatting Numbers
#
# 1. Create a variable `price = 2599.5`.
# 2. Print it with exactly two decimal places.
# 3. Print it with a thousands separator and two decimals.
# 4. Create `ratio = 0.834` and print it as a percentage with one decimal place.
# 5. Print the word `"total"` right-aligned in a width of 10 characters.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: enumerate
#
# Use the list below.
#
# 1. Loop over the list with `enumerate` and print each item with its index.
# 2. Do it again, but number the items starting from 1, like `1. apple`.

# %%
fruits = ["apple", "banana", "cherry", "date"]
# Your code here

# %% [markdown]
# ## Exercise 5: zip
#
# Use the two lists below.
#
# 1. Loop over both lists together and print `<name> scored <score>`.
# 2. Build a dictionary that maps each name to its score and print it.

# %%
names = ["Alice", "Bob", "Carol"]
scores = [85, 92, 78]
# Your code here

# %% [markdown]
# ## Exercise 6: Sorting with a Key
#
# Use the list of words below.
#
# 1. Print the list sorted alphabetically.
# 2. Print the list sorted by word length (shortest first).
# 3. Print the list sorted by length, longest first.

# %%
words = ["pear", "fig", "banana", "kiwi", "apple"]
# Your code here

# %% [markdown]
# ## Exercise 7: Nested Lists
#
# Use the grid below.
#
# 1. Print the second row.
# 2. Print the value in the third row, first column.
# 3. Loop over the grid and print every value, one row per line.
# 4. Print the sum of all the numbers in the grid.

# %%
grid = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9],
]
# Your code here

# %% [markdown]
# ## Exercise 8: Copying Lists
#
# 1. Create a list `original = [1, 2, 3]`.
# 2. Make a real copy of it called `copy`.
# 3. Append `99` to the copy only.
# 4. Print both lists to confirm the original is unchanged.

# %%
# Your code here

# %% [markdown]
# ## Exercise 9: List Comprehensions
#
# 1. Use a comprehension to build a list of the cubes of the numbers 1 to 10.
# 2. Use a comprehension to build a list of only the odd numbers from 0 to 20.
# 3. Given `words` below, use a comprehension to build a list of their lengths.
# 4. Use a comprehension to keep only the words longer than 4 characters.

# %%
words = ["sun", "cloud", "rain", "thunder", "sky"]
# Your code here

# %% [markdown]
# ## Exercise 10: Dictionary get and setdefault
#
# Use the dictionary below.
#
# 1. Try to read the key `"email"` with `.get()` so it does not error, printing `not set` if missing.
# 2. Use `.setdefault()` to add a `"country"` key with a value only if it is missing.
# 3. Print the final dictionary.

# %%
person = {"name": "Alice", "age": 30}
# Your code here

# %% [markdown]
# ## Exercise 11: Counting with a Dictionary
#
# Use the list below.
#
# 1. Count how many times each colour appears using a dictionary.
# 2. Print the counts.
# 3. Print which colour appears the most often.

# %%
colours = ["red", "blue", "red", "green", "blue", "red"]
# Your code here

# %% [markdown]
# ## Exercise 12: List of Dictionaries
#
# Use the data below.
#
# 1. Print each person's name and age.
# 2. Print the average age.
# 3. Print the names of everyone older than 28.
# 4. Print the name of the oldest person.

# %%
people = [
    {"name": "Alice", "age": 30},
    {"name": "Bob", "age": 25},
    {"name": "Carol", "age": 35},
]
# Your code here

# %% [markdown]
# ## Exercise 13: Returning Multiple Values
#
# 1. Write a function `stats(numbers)` that returns the smallest, largest, and average of a list.
# 2. Call it on `[4, 8, 1, 9, 3]` and unpack the three results into separate variables.
# 3. Print each result.

# %%
# Your code here

# %% [markdown]
# ## Exercise 14: Keyword Arguments and Defaults
#
# 1. Write a function `make_user(name, role="member", active=True)` that returns a dictionary with those three keys.
# 2. Call it with only a name.
# 3. Call it setting `role` to `"admin"`.
# 4. Call it setting `active` to `False` using a keyword argument.

# %%
# Your code here

# %% [markdown]
# ## Exercise 15: Scope
#
# 1. Create a global variable `discount = 0.1`.
# 2. Write a function `apply_discount(price)` that returns the price after subtracting the discount (it should read the global `discount`).
# 3. Call it with `200` and print the result.
# 4. Inside the function do NOT reassign `discount`; just read it.

# %%
# Your code here

# %% [markdown]
# ## Exercise 16: Docstrings
#
# 1. Write a function `area_of_circle(radius)` that returns the area (use `3.14159` for pi).
# 2. Give it a one-line docstring describing what it does.
# 3. Call it with radius `5` and print the result.
# 4. Print the function's documentation using `help()`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 17: Truthiness
#
# Use the variables below.
#
# 1. Print whether `name` is empty using a truthiness check (print `"empty"` or `"has value"`).
# 2. Print whether `items` has anything in it.
# 3. Use `or` to set `display_name` to `name` if it has a value, otherwise to `"Anonymous"`, and print it.

# %%
name = ""
items = [1, 2, 3]
# Your code here

# %% [markdown]
# ## Exercise 18: Conditional Expressions
#
# 1. Use a one-line conditional expression to set `label` to `"even"` or `"odd"` for the `number` below.
# 2. Print the label.
# 3. Using an f-string with a conditional expression, print `Pass` if `score >= 50` otherwise `Fail`.

# %%
number = 7
score = 64
# Your code here

# %% [markdown]
# ## Exercise 19: Nested Loops
#
# 1. Print a multiplication table from 1 to 5 (each row is one number times 1 through 5).
# 2. Then, given the two lists below, print every possible pairing of a topping and a size.

# %%
toppings = ["cheese", "pepperoni"]
sizes = ["small", "large"]
# Your code here

# %% [markdown]
# ## Exercise 20: random and datetime
#
# 1. Import `random` and print a random choice from `["heads", "tails"]`.
# 2. Print 6 unique random numbers between 1 and 49 (use `random.sample`).
# 3. Import `date` from `datetime` and print today's date.
# 4. Print the date 30 days from today.

# %%
# Your code here

# %% [markdown]
# ## Exercise 21: Reading Structured Data
#
# 1. Write three lines to a file called `people.txt`, each in the form `name,age` (for example `Alice,30`).
# 2. Read the file back and build a list of dictionaries with keys `name` and `age` (convert age to an integer).
# 3. Print the list.
# 4. Print the name of the oldest person.

# %%
# Your code here

# %% [markdown]
# ## Exercise 22: Error Handling
#
# 1. Write a function `to_int(text)` that tries to convert `text` to an integer inside a `try` block.
# 2. If it fails, print a friendly message and return `None`.
# 3. Test it with `"42"` and with `"hello"`.
# 4. Write a function `set_quantity(n)` that raises a `ValueError` if `n` is negative, and test it inside a `try`/`except`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 23: Mini Project — Grade Report
#
# Use the data below (a list of student dictionaries).
#
# 1. For each student, compute their average across their `scores` and print `<name>: <average>` with one decimal place.
# 2. Print the name of the student with the highest average.
# 3. Print how many students have an average of 80 or above.

# %%
students = [
    {"name": "Alice", "scores": [85, 90, 80]},
    {"name": "Bob", "scores": [70, 75, 72]},
    {"name": "Carol", "scores": [95, 88, 91]},
]
# Your code here

# %% [markdown]
# ## Exercise 24: Mini Project — Word Frequency
#
# Use the text below.
#
# 1. Convert the text to lowercase and split it into words.
# 2. Count how many times each word appears using a dictionary.
# 3. Print the three most common words with their counts, highest first.
# 4. Print how many distinct words there are.

# %%
text = "the sun is bright the sky is blue the sun is warm"
# Your code here

# %% [markdown]
# ## Self-Review Checklist
#
# After finishing, check whether you can do these without looking at the guide:
#
# - Slice strings and use common string methods.
# - Format numbers and align text with f-strings.
# - Loop with `enumerate` and `zip`.
# - Sort with a `key` function and `reverse`.
# - Work with nested lists and copy lists safely.
# - Write simple list comprehensions.
# - Access dictionaries safely and count items with them.
# - Work with lists of dictionaries.
# - Write functions that return several values and use keyword arguments.
# - Explain local vs global scope and write docstrings.
# - Use truthiness and conditional expressions.
# - Read structured data from a file and handle errors cleanly.
