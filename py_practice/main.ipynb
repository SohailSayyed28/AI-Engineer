# %% [markdown]
# Variable and Data types

# %%
#print a program to add 2 numbers
a=1
b=10
c= a+b

print(c)
# Out:
# 11

# %%
#print a program to get a remainder
a = 2050
b = 34

print(f"The remainder is {a%b}")
# Out:
# The remainder is 10

# %%
x= input("Enter a number")

print(type(x))
# Out:
# <class 'str'>
