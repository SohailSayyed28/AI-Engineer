# %% [markdown]
# Variable and Data types

# %%
#print a program to add 2 numbers
a=1
b=10
c= a+b

print(c)
# Out:
# 11

# %%
#print a program to get a remainder
a = 2050
b = 34

print(f"The remainder is {a%b}")
# Out:
# The remainder is 10

# %%
x= input("Enter a number")

print(type(x))
# Out:
# <class 'str'>

# %%
#take input and print if a is greater than b
a=int(input("Enter your number"))
b=int(input("Enter your number"))

print(a>b)
# Out:
# True

# %%
#write a program to find an average of 2 numbers by user
x=int(input("Enter your number"))
z=int(input("Enter your number"))

print(f"The average of two number is {(x+z)/2}")
# Out:
# The average of two number is 35.0

# %%
#write a program to find a square of a number by user
u=int(input("Enter your number"))

print(f"The average of two number is {u**2}")
# print(f"The average of two number is {u*u}")
# Out:
# The average of two number is 4
