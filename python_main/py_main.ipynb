# %%
print("This is my new file")
# Out:
# This is my new file

# %%
name = "Sohail" # variable
print(name)
# Out:
# Sohail

# %%
x_name = input("Enter your name") #variable using an input
print(x_name)
# Out:
# Rexa

# %%
#this is a comment


## Data types
x = 48 #int
y = "Hi" #str
z = True #bool
a = 25.6 #float
b = b23
